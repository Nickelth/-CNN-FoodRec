# %%
from keras.models import load_model
model = load_model('food_recognize_model6.h5')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 10, 6, 512)        14714688
#
#  flatten (Flatten)           (None, 30720)             0
#
#  dropout (Dropout)           (None, 30720)             0
#
#  dense (Dense)               (None, 128)               3932288
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 18,655,622
# Trainable params: 18,395,462
# Non-trainable params: 260,160
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np

# %%
img_path = 'D:\\a hamburger.jpg'
img = image.load_img(img_path,target_size = (320,200))
x = image.img_to_array(img).astype('float32')

x = np.expand_dims(x,axis = 0)

# %%
preds = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 46ms/step

# %%
print(preds)
# Out:
# [[0. 0. 1. 0. 0. 0.]]

# %%
img_path = 'D:\\a donut.jpg'
img = image.load_img(img_path,target_size = (320,200))
x = image.img_to_array(img)

x = np.expand_dims(x,axis = 0)

# %%
preds = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 64ms/step

# %%
print(preds)
# Out:
# [[1. 0. 0. 0. 0. 0.]]

# %%
img_path = 'D:\\a pizza.jpg'
img = image.load_img(img_path,target_size = (320,200))
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)

# %%
plt.imshow(img)

# %%
preds = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 39ms/step

# %%
print(preds)
# Out:
# [[0. 0. 0. 0. 1. 0.]]

# %%
img_path = 'D:\\a steak.jpg'
img = image.load_img(img_path,target_size = (320,200))
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)
preds = model.predict(x)
print(preds)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# [[0. 0. 0. 0. 0. 1.]]

# %%
img_path = 'D:\\a icecream.jpg'
img = image.load_img(img_path,target_size = (320,200))
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)
preds = model.predict(x)
print(preds)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# [[0. 0. 0. 1. 0. 0.]]

# %%
img_path = 'D:\\a eggtart.jpg'
img = image.load_img(img_path,target_size = (320,200))
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)
preds = model.predict(x)
print(preds)
# Out:
# 1/1 [==============================] - 0s 52ms/step
# [[0. 1. 0. 0. 0. 0.]]

# %%
plt.imshow(img)

# %%
from tensorflow.keras import models
layer_outputs = [layer.output for layer in model.layers[:8]]

# %%
print(model.input)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 320, 200, 3), dtype=tf.float32, name='vgg16_input'), name='vgg16_input', description="created by layer 'vgg16_input'")

# %%
import tensorflow as tf
inputs = tf.keras.Input(shape=(320,200,3))

# %%
print(inputs)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 320, 200, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")

# %%
print(layer_outputs)
# Out:
# [<KerasTensor: shape=(None, 10, 6, 512) dtype=float32 (created by layer 'block5_pool')>, <KerasTensor: shape=(None, 30720) dtype=float32 (created by layer 'flatten')>, <KerasTensor: shape=(None, 30720) dtype=float32 (created by layer 'dropout')>, <KerasTensor: shape=(None, 128) dtype=float32 (created by layer 'dense')>, <KerasTensor: shape=(None, 64) dtype=float32 (created by layer 'dense_1')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'dense_2')>]

# %%
img_path = 'D:\\a eggtart.jpg'
img = image.load_img(img_path,target_size = (320,200))
x = image.img_to_array(img)
print(x)
x = x /255
print(x)
x = np.expand_dims(x,axis = 0)
# Out:
# [[[246. 246. 246.]
#   [246. 246. 246.]
#   [246. 246. 246.]
#   ...
#   [246. 246. 246.]
#   [246. 246. 246.]
#   [246. 246. 246.]]
#
#  [[246. 246. 246.]
#   [246. 246. 246.]
#   [246. 246. 246.]
#   ...
#   [246. 246. 246.]
#   [246. 246. 246.]
#   [246. 246. 246.]]
#
#  [[246. 246. 246.]
#   [246. 246. 246.]
#   [246. 246. 246.]
#   ...
#   [246. 246. 246.]
#   [246. 246. 246.]
#   [246. 246. 246.]]
#
#  ...
#
#  [[246. 246. 246.]
#   [246. 246. 246.]
#   [246. 246. 246.]
#   ...
#   [246. 246. 246.]
#   [246. 246. 246.]
#   [246. 246. 246.]]
#
#  [[246. 246. 246.]
#   [246. 246. 246.]
#   [246. 246. 246.]
#   ...
#   [246. 246. 246.]
#   [246. 246. 246.]
#   [246. 246. 246.]]
#
#  [[246. 246. 246.]
#   [246. 246. 246.]
#   [246. 246. 246.]
#   ...
#   [246. 246. 246.]
#   [246. 246. 246.]
#   [246. 246. 246.]]]
# [[[0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   ...
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]]
#
#  [[0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   ...
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]]
#
#  [[0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   ...
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]]
#
#  ...
#
#  [[0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   ...
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]]
#
#  [[0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   ...
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]]
#
#  [[0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   ...
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]
#   [0.9647059 0.9647059 0.9647059]]]

# %%
plt.figure(figsize = (15,30))
img_path = 'D:\\food_dataset\\food_dataset\\train\\'
foods = ['donuts','egg_tart','hamburger','ice_cream','pizza','steak']
cnt = 0

for j in range(6):
    curpath = img_path + foods[j]
  
    for i in range(5):
        p = curpath + "\\" + str(i) +'.jpg'
        img = image.load_img(p,target_size = (320,200))
        
        plt.subplot(6,5,i + cnt + 1)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(img)
    cnt += 5
